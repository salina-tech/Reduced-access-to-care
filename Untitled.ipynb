# %%
import pandas as pd
import numpy as np

# %%
PD_care = pd.read_csv('Reduced_Access_to_Care_During_COVID-19.csv')

# %%
PD_care.head(10)
# Out:
#    Round                         Indicator      Group           Subgroup  \
# 0      1  Reduced access to emergency care  Age group        18-44 years
# 1      1  Reduced access to emergency care  Age group        18-44 years
# 2      1  Reduced access to emergency care  Age group        45-64 years
# 3      1  Reduced access to emergency care  Age group        45-64 years
# 4      1  Reduced access to emergency care  Age group  65 years and over
# 5      1  Reduced access to emergency care  Age group  65 years and over
# 6      2  Reduced access to emergency care  Age group        18-44 years
# 7      2  Reduced access to emergency care  Age group        18-44 years
# 8      2  Reduced access to emergency care  Age group        45-64 years
# 9      2  Reduced access to emergency care  Age group        45-64 years
#
#           Response  Percent  Standard Error  Suppression  Significant 1  \
# 0   For any reason      2.4             0.4          NaN            NaN
# 1  Due to pandemic      1.4             0.4          NaN            NaN
# 2   For any reason      3.3             0.4          NaN            NaN
# 3  Due to pandemic      2.1             0.4          NaN            NaN
# 4   For any reason      4.3             0.7          NaN            NaN
# 5  Due to pandemic      3.6             0.6          NaN            NaN
# 6   For any reason      3.2             0.5          NaN            0.0
# 7  Due to pandemic      1.6             0.3          NaN            0.0
# 8   For any reason      3.3             0.7          NaN            0.0
# 9  Due to pandemic      1.8             0.5          NaN            0.0
#
#    Significant 2
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN

# %%
PD_care.drop(['Standard Error', 'Suppression', 'Significant 1', 'Significant 2'], axis = 1, inplace = True)
PD_care.head()
# Out:
#    Round                         Indicator      Group           Subgroup  \
# 0      1  Reduced access to emergency care  Age group        18-44 years
# 1      1  Reduced access to emergency care  Age group        18-44 years
# 2      1  Reduced access to emergency care  Age group        45-64 years
# 3      1  Reduced access to emergency care  Age group        45-64 years
# 4      1  Reduced access to emergency care  Age group  65 years and over
#
#           Response  Percent
# 0   For any reason      2.4
# 1  Due to pandemic      1.4
# 2   For any reason      3.3
# 3  Due to pandemic      2.1
# 4   For any reason      4.3

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
labels = ['Round1', 'Round2', 'Round3']
eighteen_Fourty_Four = [2.4, 3.2, 3.8]
Fourty_Five_Sixty_Four = [3.3, 3.3, 2.6]
Sixty_Five_Over = [4.3, 3.7, 2.7]

x = np.arange(len(labels))  # the label locations
width =0.09# the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-0.1, eighteen_Fourty_Four, width, label='18 to 44')
rects2 = ax.bar(x, Fourty_Five_Sixty_Four, width, label='45 to 64')
rects3 = ax.bar(x+0.1, Sixty_Five_Over, width, label='65+')

plt.xlabel('Round') 
Round = [1,2,3]

ax.set_ylabel('Percentage of reduced access to care')
ax.set_title('Percentage of reduced access to care for any other reason than COVID-19')
ax.set_xticks(x, labels)
ax.legend()

stacked=False
plt.xticks(x, ['Round1', 'Round 2', 'Round 3'])


fig.tight_layout()


plt.show()

# %%
labels = ['Round1', 'Round2', 'Round3']
eighteen_Fourty_Four = [1.4, 1.6, 0.9]
Fourty_Five_Sixty_Four = [2.1, 1.8, 0.6]
Sixty_Five_Over = [3.6, 2.8, 0.6]

x = np.arange(len(labels))  # the label locations
width =0.09# the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-0.1, eighteen_Fourty_Four, width, label='18 to 44')
rects2 = ax.bar(x, Fourty_Five_Sixty_Four, width, label='45 to 64')
rects3 = ax.bar(x+0.1, Sixty_Five_Over, width, label='65+')

plt.xlabel('Round') 
Round = [1,2,3]

ax.set_ylabel('Percentage of reduced access to care')
ax.set_title('Percentage of reduced access to care due to COVID-19')
ax.set_xticks(x, labels)
ax.legend()

stacked=False
plt.xticks(x, ['Round1', 'Round 2', 'Round 3'])


fig.tight_layout()


plt.show()
