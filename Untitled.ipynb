# %% [markdown]
# RANDS during COVID-19 included questions about unmet care in the last 2 months during the coronavirus pandemic. Unmet needs for health care are often the result of cost-related barriers. The National Health Interview Survey, conducted by NCHS, is the source for high-quality data to monitor cost-related health care access problems in the United States. For example, in 2018, 7.3% of persons of all ages reported delaying medical care due to cost and 4.8% reported needing medical care but not getting it due to cost in the past year. However, cost is not the only reason someone might delay or not receive needed medical care. As a result of the coronavirus pandemic, people also may not get needed medical care due to cancelled appointments, cutbacks in transportation options, fear of going to the emergency room, or an altruistic desire to not be a burden on the health care system, among other reasons.

# %%
import pandas as pd
import numpy as np

# %%
PD_care = pd.read_csv('Reduced_Access_to_Care_During_COVID-19.csv')

# %%
PD_care.head(10)
# Out:
#    Round                             Indicator  Group Subgroup  \
# 0      1  Reduced access to surgical procedure  Total    Total
# 1      1  Reduced access to surgical procedure  Total    Total
# 2      1  Reduced access to surgical procedure  Total    Total
# 3      2  Reduced access to surgical procedure  Total    Total
# 4      2  Reduced access to surgical procedure  Total    Total
# 5      2  Reduced access to surgical procedure  Total    Total
# 6      3  Reduced access to surgical procedure  Total    Total
# 7      3  Reduced access to surgical procedure  Total    Total
# 8      3  Reduced access to surgical procedure  Total    Total
#
#    Total sample size         Response  Sample size Percent  Standard Error  \
# 0             6679.0              NaN          NaN     NaN             NaN
# 1                NaN   For any reason        361.0      5%             0.5
# 2                NaN  Due to pandemic        267.0      4%             0.3
# 3             5902.0              NaN          NaN     NaN             NaN
# 4                NaN   For any reason        254.0      4%             0.4
# 5                NaN  Due to pandemic        159.0      3%             0.3
# 6             5400.0              NaN          NaN     NaN             NaN
# 7                NaN   For any reason        189.0      4%             0.4
# 8                NaN  Due to pandemic         65.0      1%             0.2
#
#    Suppression  Significant 1  Significant 2
# 0          NaN            NaN            NaN
# 1          NaN            NaN            NaN
# 2          NaN            NaN            NaN
# 3          NaN            NaN            NaN
# 4          NaN            1.0            NaN
# 5          NaN            1.0            NaN
# 6          NaN            NaN            NaN
# 7          NaN            1.0            0.0
# 8          NaN            1.0            1.0

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
